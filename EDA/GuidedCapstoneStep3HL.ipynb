# %% [markdown]
# # Guided Capstone Step 3 Exploratory Data Analysis

# %% [markdown]
# This is the third step in the Data Science Method. We introduced this topic in the last subunit. With Data Wrangling out of the way we can progress to the Exploratory Data Analysis section. In this exercise, you will learn to build data profiles and plots, including relationship plot and data correlation plot. You will also implement k-means clustering, complete clusters, and update data frame as a CSV file. Let's get started!
#
# **The Data Science Method**
#
#
# 1.   Problem Identification
#
# 2.   Data Wrangling
#   * Data Collection
#    * Data Organization
#   * Data Definition
#   * Data Cleaning
#
# 3.   **Exploratory Data Analysis**
#  * Build data profile tables and plots
#         - Outliers & Anomalies
#  * Explore data relationships
#  * Identification and creation of features
#
# 4.   Pre-processing and Training Data Development
#   * Create dummy or indicator features for categorical variables
#   * Standardize the magnitude of numeric features
#   * Split into testing and training datasets
#   * Apply scaler to the testing set
# 5.   Modeling
#   * Fit Models with Training Data Set
#   * Review Model Outcomes — Iterate over additional models as needed.
#   * Identify the Final Model
#
# 6.   Documentation
#   * Review the Results
#   * Present and share your findings - storytelling
#   * Finalize Code
#   * Finalize Documentation

# %% [markdown]
# **<font color='teal'> Start by loading the necessary packages as we did in step 2 and printing out our current working directory just to confirm we are in the correct project directory. </font>**

# %%
#load python packages
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
os.getcwd()
# Out:
# 'C:\\Users\\pavilion\\Desktop\\Rahul\\Springboard\\Springboard_May_20\\material\\GuidedCapstoneProject\\Step 2\\data'

# %% [markdown]
# **<font color='teal'> If you need to change your path refer back to step 2 on how to do that. Then load the csv file you created in step 2, remember it should be saved inside your data subfolder and print the first five rows.</font>**

# %%
df = pd.read_csv('step2_output.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                 Name   Region    state  summit_elev  \
# 0           0       Alyeska Resort   Alaska   Alaska         3939
# 1           1  Eaglecrest Ski Area   Alaska   Alaska         2600
# 2           2     Hilltop Ski Area   Alaska   Alaska         2090
# 3           3     Arizona Snowbowl  Arizona  Arizona        11500
# 4           4  Sunrise Park Resort  Arizona  Arizona        11100
#
#    vertical_drop  base_elev  trams  fastEight  fastSixes  ...  LongestRun_mi  \
# 0           2500        250      1        0.0          0  ...            1.0
# 1           1540       1200      0        0.0          0  ...            2.0
# 2            294       1796      0        0.0          0  ...            1.0
# 3           2300       9200      0        0.0          1  ...            2.0
# 4           1800       9200      0        0.0          0  ...            1.2
#
#    SkiableTerrain_ac  Snow Making_ac  daysOpenLastYear  yearsOpen  \
# 0             1610.0           113.0             150.0       60.0
# 1              640.0            60.0              45.0       44.0
# 2               30.0            30.0             150.0       36.0
# 3              777.0           104.0             122.0       81.0
# 4              800.0            80.0             115.0       49.0
#
#    averageSnowfall  AdultWeekday  AdultWeekend  projectedDaysOpen  \
# 0            669.0          65.0          85.0              150.0
# 1            350.0          47.0          53.0               90.0
# 2             69.0          30.0          34.0              152.0
# 3            260.0          89.0          89.0              122.0
# 4            250.0          74.0          78.0              104.0
#
#    NightSkiing_ac
# 0           550.0
# 1             NaN
# 2            30.0
# 3             NaN
# 4            80.0
#
# [5 rows x 28 columns]

# %% [markdown]
# # Build data profile tables and plots

# %% [markdown]
# **<font color='teal'> Print out the summary stats table transposed to fit on the screen using the `describe()` function.</font>**

# %%
df.describe().T
# Out:
#                    count         mean          std    min      25%  \
# Unnamed: 0         330.0   164.500000    95.407023    0.0    82.25
# summit_elev        330.0  4591.818182  3735.535934  315.0  1403.75
# vertical_drop      330.0  1215.427273   947.864557   60.0   461.25
# base_elev          330.0  3374.000000  3117.121621   70.0   869.00
# trams              330.0     0.172727     0.559946    0.0     0.00
# fastEight          330.0     0.003030     0.055048    0.0     0.00
# fastSixes          330.0     0.184848     0.651685    0.0     0.00
# fastQuads          330.0     1.018182     2.198294    0.0     0.00
# quad               330.0     0.933333     1.312245    0.0     0.00
# triple             330.0     1.500000     1.619130    0.0     0.00
# double             330.0     1.833333     1.815028    0.0     1.00
# surface            330.0     2.621212     2.059636    0.0     1.00
# total_chairs       330.0     8.266667     5.798683    0.0     5.00
# Runs               330.0    48.214724    46.081366    3.0    19.00
# TerrainParks       330.0     2.384848     2.109556    0.0     1.00
# LongestRun_mi      330.0     1.433231     1.147352    0.0     0.60
# SkiableTerrain_ac  330.0   739.801223  1807.868079    8.0    85.00
# Snow Making_ac     330.0   150.496970   249.854380    0.0    30.00
# daysOpenLastYear   330.0   115.103943    32.231212    3.0   100.00
# yearsOpen          330.0    63.481818   109.309582    6.0    50.00
# averageSnowfall    330.0   185.316456   133.424094   18.0    71.25
# AdultWeekday       330.0    57.916957    23.898798   15.0    43.00
# AdultWeekend       330.0    64.166810    22.571324   17.0    49.00
# projectedDaysOpen  330.0   120.053004    28.742976   30.0   101.25
# NightSkiing_ac     187.0   100.395722   105.169620    2.0    40.00
#
#                            50%          75%      max
# Unnamed: 0          164.500000   246.750000    329.0
# summit_elev        3127.500000  7806.000000  13487.0
# vertical_drop       964.500000  1800.000000   4425.0
# base_elev          1561.500000  6325.250000  10800.0
# trams                 0.000000     0.000000      4.0
# fastEight             0.000000     0.000000      1.0
# fastSixes             0.000000     0.000000      6.0
# fastQuads             0.000000     1.000000     15.0
# quad                  0.000000     1.000000      8.0
# triple                1.000000     2.000000      8.0
# double                1.000000     3.000000     14.0
# surface               2.000000     3.000000     15.0
# total_chairs          7.000000    10.000000     41.0
# Runs                 34.000000    60.000000    341.0
# TerrainParks          2.000000     3.000000     14.0
# LongestRun_mi         1.000000     2.000000      6.0
# SkiableTerrain_ac   200.000000   739.801223  26819.0
# Snow Making_ac       86.000000   192.000000   3379.0
# daysOpenLastYear    115.103943   130.000000    305.0
# yearsOpen            58.000000    68.750000   2019.0
# averageSnowfall     158.000000   278.750000    669.0
# AdultWeekday         57.916957    67.000000    179.0
# AdultWeekend         64.166810    72.000000    179.0
# projectedDaysOpen   120.053004   136.000000    305.0
# NightSkiing_ac       72.000000   114.000000    650.0

# %% [markdown]
# **<font color='teal'> Histograms are an excellent way to review the range and density of values for each numeric features in your data set and build data profiles. Plot the histograms for all numeric features and adjust the bins size to 25.</font>**

# %%
df_num = df.select_dtypes(include='number')

# %%
df_num.head()
# Out:
#    Unnamed: 0  summit_elev  vertical_drop  base_elev  trams  fastEight  \
# 0           0         3939           2500        250      1        0.0
# 1           1         2600           1540       1200      0        0.0
# 2           2         2090            294       1796      0        0.0
# 3           3        11500           2300       9200      0        0.0
# 4           4        11100           1800       9200      0        0.0
#
#    fastSixes  fastQuads  quad  triple  ...  LongestRun_mi  SkiableTerrain_ac  \
# 0          0          2     2       0  ...            1.0             1610.0
# 1          0          0     0       0  ...            2.0              640.0
# 2          0          0     0       1  ...            1.0               30.0
# 3          1          0     2       2  ...            2.0              777.0
# 4          0          1     2       3  ...            1.2              800.0
#
#    Snow Making_ac  daysOpenLastYear  yearsOpen  averageSnowfall  AdultWeekday  \
# 0           113.0             150.0       60.0            669.0          65.0
# 1            60.0              45.0       44.0            350.0          47.0
# 2            30.0             150.0       36.0             69.0          30.0
# 3           104.0             122.0       81.0            260.0          89.0
# 4            80.0             115.0       49.0            250.0          74.0
#
#    AdultWeekend  projectedDaysOpen  NightSkiing_ac
# 0          85.0              150.0           550.0
# 1          53.0               90.0             NaN
# 2          34.0              152.0            30.0
# 3          89.0              122.0             NaN
# 4          78.0              104.0            80.0
#
# [5 rows x 25 columns]

# %%
df_num = df_num.fillna(0)

# %%
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330 entries, 0 to 329
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         330 non-null    int64
#  1   summit_elev        330 non-null    int64
#  2   vertical_drop      330 non-null    int64
#  3   base_elev          330 non-null    int64
#  4   trams              330 non-null    int64
#  5   fastEight          330 non-null    float64
#  6   fastSixes          330 non-null    int64
#  7   fastQuads          330 non-null    int64
#  8   quad               330 non-null    int64
#  9   triple             330 non-null    int64
#  10  double             330 non-null    int64
#  11  surface            330 non-null    int64
#  12  total_chairs       330 non-null    int64
#  13  Runs               330 non-null    float64
#  14  TerrainParks       330 non-null    float64
#  15  LongestRun_mi      330 non-null    float64
#  16  SkiableTerrain_ac  330 non-null    float64
#  17  Snow Making_ac     330 non-null    float64
#  18  daysOpenLastYear   330 non-null    float64
#  19  yearsOpen          330 non-null    float64
#  20  averageSnowfall    330 non-null    float64
#  21  AdultWeekday       330 non-null    float64
#  22  AdultWeekend       330 non-null    float64
#  23  projectedDaysOpen  330 non-null    float64
#  24  NightSkiing_ac     330 non-null    float64
# dtypes: float64(13), int64(12)
# memory usage: 64.6 KB

# %%
df_num.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C10E8908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C1329D08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C335AF48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C3398048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C33D1188>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C3406288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C3430108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C347A4C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C3486088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C34BF1C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C3523788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C355A8C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C35929C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C35C9A48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C3602B88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C363AC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C3672D88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C36AAEC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C36E3FC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C371E088>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C37571C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C378F2C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C37C83C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C37FD508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C3838588>]],
#       dtype=object)

# %%
df_num1 = df_num.iloc[:,0:4]
df_num1.head()
# Out:
#    Unnamed: 0  summit_elev  vertical_drop  base_elev
# 0           0         3939           2500        250
# 1           1         2600           1540       1200
# 2           2         2090            294       1796
# 3           3        11500           2300       9200
# 4           4        11100           1800       9200

# %%
for i,col in enumerate(df_num1.columns):
    plt.figure(i)
    sns.distplot(df_num1[col])

# %%
df_num2 = df_num.iloc[:,7:]
df_num2.head()
# Out:
#    fastQuads  quad  triple  double  surface  total_chairs  Runs  TerrainParks  \
# 0          2     2       0       0        2             7  76.0           2.0
# 1          0     0       0       4        0             4  36.0           1.0
# 2          0     0       1       0        2             3  13.0           1.0
# 3          0     2       2       1        2             8  55.0           4.0
# 4          1     2       3       1        0             7  65.0           2.0
#
#    LongestRun_mi  SkiableTerrain_ac  Snow Making_ac  daysOpenLastYear  \
# 0            1.0             1610.0           113.0             150.0
# 1            2.0              640.0            60.0              45.0
# 2            1.0               30.0            30.0             150.0
# 3            2.0              777.0           104.0             122.0
# 4            1.2              800.0            80.0             115.0
#
#    yearsOpen  averageSnowfall  AdultWeekday  AdultWeekend  projectedDaysOpen  \
# 0       60.0            669.0          65.0          85.0              150.0
# 1       44.0            350.0          47.0          53.0               90.0
# 2       36.0             69.0          30.0          34.0              152.0
# 3       81.0            260.0          89.0          89.0              122.0
# 4       49.0            250.0          74.0          78.0              104.0
#
#    NightSkiing_ac
# 0           550.0
# 1             0.0
# 2            30.0
# 3             0.0
# 4            80.0

# %%
for i,col in enumerate(df_num2.columns):
    plt.figure(i)
    sns.distplot(df_num2[col])

# %%
df_num.iloc[:,[4,5,6]].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C4904488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C5915248>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C3E63A08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C4524448>]],
#       dtype=object)

# %%
import os, sys
from scipy import stats
import numpy as np

for index, line in enumerate(open('data2.txt', 'r').readlines()):
    w = line.split(' ')
    l1 = w[1:8]
    l2 = w[8:15]

    try:
        list1 = map(float, l1)
        list2 = map(float, l2)
    except ValueError:
        print 'Line {i} is corrupt!'.format(i = index)'
        break

    result = stats.ttest_ind(list1, list2)
    print result[1]
# Out:
#   File "<ipython-input-31-c932f162371d>", line 14
#     print 'Line {i} is corrupt!'.format(i = index)'
#                                ^
# SyntaxError: invalid syntax

# %%
df_num.groupby('fastEight').nunique()

# %%
#df = df.drop('Unnamed: 0', axis=1)
df_num = df.select_dtypes(include=[np.number])
#df_num = df_num.drop('NightSkiing_ac', axis=1)
for i,col in enumerate(df_num.columns):
    print(col)
    plt.figure(i)
    sns.distplot(df[col])

# %%
df_num.columns

# %%
df['fastSixes'].hist()

# %%
df_num.dtypes

# %% [markdown]
# Look for similarities in the features that may indicate that they are duplicates or highly correlated features. Make a note of your findings and any other interesting insights you find about these numeric features.

# %% [markdown]
# **<font color='teal'> Okay, now you should be getting a sense for what the data look like. Let's create a barplot for the categorical features `Region` and `state` where the heights of the bars are the counts of each level in that variable. </font>**

# %% [markdown]
# **<font color='teal'>State Levels Plot</font>**

# %%
# Uncomment the following code to get your visualization started 
f, ax = plt.subplots(figsize=(10, 10))

# In the following brackets, we want the value_counts() of the states 
x = pd.DataFrame(df.state.value_counts())

# Get the state names by calling list() on the x.index
names = list(x.index)

# Get the values by plugging x.state into the list() function
values = list(x.state)

# We're now going to call the barplot() method on our sns seaborn object. 
# If you don't have a searborn object yet, make sure you've imported seaborn as sns in your imports above. 
sns.barplot(x=values, y=names, palette="RdBu_r")

# %%
x.head()
# Out:
#               state
# New York         33
# Michigan         29
# Colorado         22
# California       21
# Pennsylvania     19

# %% [markdown]
# **<font color='teal'>Region Levels Plot</font>**

# %%
# Now do the same for regions!

# %%
# Uncomment the following code to get your visualization started 
f, ax = plt.subplots(figsize=(10, 10))

# In the following brackets, we want the value_counts() of the states 
y = pd.DataFrame(df.Region.value_counts())

# Get the state names by calling list() on the x.index
names = list(y.index)

# Get the values by plugging x.state into the list() function
values = list(y.Region)

# We're now going to call the barplot() method on our sns seaborn object. 
# If you don't have a searborn object yet, make sure you've imported seaborn as sns in your imports above. 
sns.barplot(x=values, y=names, palette="RdBu_r")

# %% [markdown]
# By reviewing the State and Regions counts plots you should notice that the Region feature is nearly identical to the state and therfore we can remove from the dataframe.**<font color='teal'> Remove the `Region` column using the drop function.</font>**

# %%
df.drop(['Region'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330 entries, 0 to 329
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         330 non-null    int64
#  1   Name               330 non-null    object
#  2   state              330 non-null    object
#  3   summit_elev        330 non-null    int64
#  4   vertical_drop      330 non-null    int64
#  5   base_elev          330 non-null    int64
#  6   trams              330 non-null    int64
#  7   fastEight          330 non-null    float64
#  8   fastSixes          330 non-null    int64
#  9   fastQuads          330 non-null    int64
#  10  quad               330 non-null    int64
#  11  triple             330 non-null    int64
#  12  double             330 non-null    int64
#  13  surface            330 non-null    int64
#  14  total_chairs       330 non-null    int64
#  15  Runs               330 non-null    float64
#  16  TerrainParks       330 non-null    float64
#  17  LongestRun_mi      330 non-null    float64
#  18  SkiableTerrain_ac  330 non-null    float64
#  19  Snow Making_ac     330 non-null    float64
#  20  daysOpenLastYear   330 non-null    float64
#  21  yearsOpen          330 non-null    float64
#  22  averageSnowfall    330 non-null    float64
#  23  AdultWeekday       330 non-null    float64
#  24  AdultWeekend       330 non-null    float64
#  25  projectedDaysOpen  330 non-null    float64
#  26  NightSkiing_ac     187 non-null    float64
# dtypes: float64(13), int64(12), object(2)
# memory usage: 69.7+ KB

# %% [markdown]
# ## Anamolies & Outliers - Review boxplots

# %% [markdown]
# **<font color='teal'> Print boxplot for every column</font>**
#
# Hint: you'll see the methodology here in this article on Exploratory Data Analysis [here](nce-method-dsm-exploratory-data-analysis-bc84d4d8d3f9).

# %%
df.boxplot()
plt.show()

# %%
for i,col in enumerate(df_num.columns) :# unable to plot box plot for each column in seperate figures
    plt.figure(i)
    sns.boxplot(df_num[col],data=df_num)
# Out:
# C:\Users\pavilion\Anaconda3\New folder\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# C:\Users\pavilion\Anaconda3\New folder\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# C:\Users\pavilion\Anaconda3\New folder\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# C:\Users\pavilion\Anaconda3\New folder\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# C:\Users\pavilion\Anaconda3\New folder\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
df['summit_elev'].plot(kind='box')

# %%
sns.boxplot(df['summit_elev'],data=df)

# %% [markdown]
# You need to create boxplots and  histograms to evaluate the data for potential outliers or data anomalies. Generally, outliers are defined as observations that differ significantly from the other values in the dataset or feature.
#
# Reviewing the distribution of values by column will help you  interpret this. Outliers are extreme values that fall far outside the mean and standard deviation of a set of observations. They  can mislead the training process in building machine learning models. Outliers may be real anomalies in the observations or artificial errors.
#
# One method for outlier analysis is extreme value analysis using a boxplot, which assumes a normal distribution. The figure below describes the components of a boxplot. Notice the outlier is the point outside the upper whisker end.
#
# ![](AnnotatedBoxplot.png)
# <font color='teal'>Follow these steps:
#
# 1. Create boxplots - earlier step
# 2. Apply outlier removal using the Interquartile range or replacement
# 3. Review how many observations were removed</font>
#
# Hint: Recall from your statistics prework that a common definition of an outlier is an observation lying more than (1.5 * the Interquartile range) above the third quartile, or more than just that much below the first quartile.

# %%
# Let's get the Interquartile range, or IQR. This is equal to Q3 - Q1. 
# First, let's use the quantile() method to get the first quartile, and store it in a variable called Q1.
# We'll want to plug 0.25 into the quantile method. 
Q1 = df.quantile(0.25)

# Now get Q3 and store in a variable called Q3. 
Q3 = df.quantile(0.75)
# Now calculate the IQR, storing it in a variable called IQR.
IQR = Q3-Q1
# Make a variable called `dfno`, and assign it the value: df[~((df < (Q1 - 1.5 * IQR)) |(df> (Q3 + 1.5 * IQR))).any(axis=1)]. 
# This filters on our existing dataframe, picking out just those observations that are NOT outliers. 
dfno = df[~((df < (Q1 - 1.5 * IQR)) |(df> (Q3 + 1.5 * IQR))).any(axis=1)]
# We now want to make a boxplot of this new dataframe dfno. 
fig = dfno.boxplot(grid=False, vert=False,fontsize=15, figsize=(12,15))

# %%
# Print the shapes of our dataframes df and dfno to compare the number of observations in each. 
df.shape
# Out:
# (330, 27)

# %%
dfno.shape
# Out:
# (175, 27)

# %% [markdown]
# There are many ways to discover and remove outliers, and what counts as a sensible way of doing so depends on your problem, your methodology for solving that problem, and the nature of your data.
#
# Each method will have its merits and demerits. As we can see, in this instance, we've lost a great many observations!
#
# There is no hard and fast rule as to which outlier removal method is best in all cases, and you will have to exercise your good judgement in arriving at an appropriate method for your problem at hand. We will cover outlier removal in more depth in units 7 (Data Wrangling) and 10 (Statistics for Exploratory Data Analysis) of the course.

# %% [markdown]
# There are many possible response variables you could have identified in Step 1 of this guided capstone. However, for the rest of this guided capstone project, we will focus on increasing revenue by increasing the lift ticket prices and the number of days the resort is open per year. In this case, we need to investigate the expected lift ticket price for Big Mountain based on all the other given resort characteristics. In addition, we want to predict the number of days the resort will be open each season.

# %% [markdown]
# <font color='teal'>**Review the `AdultWeekday`,`AdultWeekend` response variable distributions**</font>

# %%
# Make a histogram of the 'AdultWeekday' column of the dfno dataframe. 
# You'll want to call hist() on that column 
dfno[['AdultWeekday','AdultWeekend']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C7A09148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D2C7A33408>]],
#       dtype=object)

# %% [markdown]
# <font color='teal'>**Review the `daysOpenLastYear`,`projecteDaysOpen` response variable distributions**</font>

# %%
# Do the same as above! You got this :)

# %%
dfno['daysOpenLastYear'].hist()
plt.xlabel('Day open last year')
plt.ylabel('no of resorts')
plt.show()

# %%
dfno.hist(['projectedDaysOpen'])
plt.xlabel('Projected open days')
plt.ylabel('no of resorts')
plt.show()

# %% [markdown]
# After reviewing these respons varible distributions, there doesn't appear to be any data issues to mitigate. Now, we move on to investigating feature relationship and interactions between the features the response.

# %% [markdown]
# # Explore data relationships

# %% [markdown]
# <font color='teal'>**Create pairplots or what is commonly referred to as biplots**</font>
#
# Hint: pairplots are covered in this article on EDA [here](https://medium.com/@aiden.dataminer/the-data-science-method-dsm-exploratory-data-analysis-bc84d4d8d3f9).

# %%
g = sns.pairplot(dfno)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-7d61f791fbff> in <module>
# ----> 1 g = sns.pairplot(dfno)
#
# ~\Anaconda3\New folder\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2092     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2093                     hue_order=hue_order, palette=palette, corner=corner,
# -> 2094                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    2095
#    2096     # Add the markers here as PairGrid has figured out how many levels of the
#
# ~\Anaconda3\New folder\lib\site-packages\seaborn\axisgrid.py in __init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, corner, diag_sharey, height, aspect, layout_pad, despine, dropna, size)
#    1348             self._despine = True
#    1349             utils.despine(fig=fig)
# -> 1350         fig.tight_layout(pad=layout_pad)
#    1351
#    1352     def map(self, func, **kwargs):
#
# ~\Anaconda3\New folder\lib\site-packages\matplotlib\figure.py in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    2474         kwargs = get_tight_layout_figure(
#    2475             self, self.axes, subplotspec_list, renderer,
# -> 2476             pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    2477         if kwargs:
#    2478             self.subplots_adjust(**kwargs)
#
# ~\Anaconda3\New folder\lib\site-packages\matplotlib\tight_layout.py in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     360                                      subplot_list=subplot_list,
#     361                                      ax_bbox_list=ax_bbox_list,
# --> 362                                      pad=pad, h_pad=h_pad, w_pad=w_pad)
#     363
#     364     # kwargs can be none if tight_layout fails...
#
# ~\Anaconda3\New folder\lib\site-packages\matplotlib\tight_layout.py in auto_adjust_subplotpars(fig, renderer, nrows_ncols, num1num2_list, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#     109             continue
#     110
# --> 111         tight_bbox_raw = union([ax.get_tightbbox(renderer) for ax in subplots
#     112                                 if ax.get_visible()])
#     113         tight_bbox = TransformedBbox(tight_bbox_raw,
#
# ~\Anaconda3\New folder\lib\site-packages\matplotlib\tight_layout.py in <listcomp>(.0)
#     110
#     111         tight_bbox_raw = union([ax.get_tightbbox(renderer) for ax in subplots
# --> 112                                 if ax.get_visible()])
#     113         tight_bbox = TransformedBbox(tight_bbox_raw,
#     114                                      fig.transFigure.inverted())
#
# ~\Anaconda3\New folder\lib\site-packages\matplotlib\axes\_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4367         bb.append(axbbox)
#    4368
# -> 4369         self._update_title_position(renderer)
#    4370         if self.title.get_visible():
#    4371             bb.append(self.title.get_window_extent(renderer))
#
# ~\Anaconda3\New folder\lib\site-packages\matplotlib\axes\_base.py in _update_title_position(self, renderer)
#    2547                     if (ax.xaxis.get_label_position() == 'top' or
#    2548                             ax.xaxis.get_ticks_position() in choices):
# -> 2549                         bb = ax.xaxis.get_tightbbox(renderer)
#    2550                     else:
#    2551                         bb = ax.get_window_extent(renderer)
#
# ~\Anaconda3\New folder\lib\site-packages\matplotlib\axis.py in get_tightbbox(self, renderer)
#    1160             return
#    1161
# -> 1162         ticks_to_draw = self._update_ticks()
#    1163
#    1164         self._update_label_position(renderer)
#
# ~\Anaconda3\New folder\lib\site-packages\matplotlib\axis.py in _update_ticks(self)
#    1085             tick.set_label1(label)
#    1086             tick.set_label2(label)
# -> 1087         minor_locs = self.get_minorticklocs()
#    1088         minor_labels = self.minor.formatter.format_ticks(minor_locs)
#    1089         minor_ticks = self.get_minor_ticks(len(minor_locs))
#
# ~\Anaconda3\New folder\lib\site-packages\matplotlib\axis.py in get_minorticklocs(self)
#    1327         """Get the array of minor tick locations in data coordinates."""
#    1328         # Remove minor ticks duplicating major ticks.
# -> 1329         major_locs = self.major.locator()
#    1330         minor_locs = self.minor.locator()
#    1331         transform = self._scale.get_transform()
#
# ~\Anaconda3\New folder\lib\site-packages\matplotlib\ticker.py in __call__(self)
#    2079     def __call__(self):
#    2080         vmin, vmax = self.axis.get_view_interval()
# -> 2081         return self.tick_values(vmin, vmax)
#    2082
#    2083     def tick_values(self, vmin, vmax):
#
# ~\Anaconda3\New folder\lib\site-packages\matplotlib\ticker.py in tick_values(self, vmin, vmax)
#    2087         vmin, vmax = mtransforms.nonsingular(
#    2088             vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2089         locs = self._raw_ticks(vmin, vmax)
#    2090
#    2091         prune = self._prune
#
# ~\Anaconda3\New folder\lib\site-packages\matplotlib\ticker.py in _raw_ticks(self, vmin, vmax)
#    2026         if self._nbins == 'auto':
#    2027             if self.axis is not None:
# -> 2028                 nbins = np.clip(self.axis.get_tick_space(),
#    2029                                 max(1, self._min_n_ticks - 1), 9)
#    2030             else:
#
# ~\Anaconda3\New folder\lib\site-packages\matplotlib\axis.py in get_tick_space(self)
#    2181         ends = self.axes.transAxes.transform([[0, 0], [1, 0]])
#    2182         length = ((ends[1][0] - ends[0][0]) / self.axes.figure.dpi) * 72
# -> 2183         tick = self._get_tick(True)
#    2184         # There is a heuristic here that the aspect ratio of tick text
#    2185         # is no more than 3:1
#
# ~\Anaconda3\New folder\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    1931         else:
#    1932             tick_kw = self._minor_tick_kw
# -> 1933         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1934
#    1935     def _get_label(self):
#
# ~\Anaconda3\New folder\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     156         self.apply_tickdir(tickdir)
#     157
# --> 158         self.tick1line = self._get_tick1line()
#     159         self.tick2line = self._get_tick2line()
#     160         self.gridline = self._get_gridline()
#
# ~\Anaconda3\New folder\lib\site-packages\matplotlib\axis.py in _get_tick1line(self)
#     462                           linestyle='None', marker=self._tickmarkers[0],
#     463                           markersize=self._size,
# --> 464                           markeredgewidth=self._width, zorder=self._zorder)
#     465         l.set_transform(self.axes.get_xaxis_transform(which='tick1'))
#     466         self._set_artist_props(l)
#
# ~\Anaconda3\New folder\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     380         self._color = None
#     381         self.set_color(color)
# --> 382         self._marker = MarkerStyle(marker, fillstyle)
#     383
#     384         self._markevery = None
#
# ~\Anaconda3\New folder\lib\site-packages\matplotlib\markers.py in __init__(self, marker, fillstyle)
#     241         self._marker_function = None
#     242         self.set_fillstyle(fillstyle)
# --> 243         self.set_marker(marker)
#     244
#     245     def _recache(self):
#
# ~\Anaconda3\New folder\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     314
#     315         self._marker = marker
# --> 316         self._recache()
#     317
#     318     def get_path(self):
#
# ~\Anaconda3\New folder\lib\site-packages\matplotlib\markers.py in _recache(self)
#     254         self._capstyle = 'butt'
#     255         self._filled = True
# --> 256         self._marker_function()
#     257
#     258     def __bool__(self):
#
# ~\Anaconda3\New folder\lib\site-packages\matplotlib\markers.py in _set_tickdown(self)
#     767
#     768     def _set_tickdown(self):
# --> 769         self._transform = Affine2D().scale(1.0, -1.0)
#     770         self._snap_threshold = 1.0
#     771         self._filled = False
#
# ~\Anaconda3\New folder\lib\site-packages\matplotlib\transforms.py in scale(self, sx, sy)
#    1989         scale_mtx = np.array(
#    1990             [[sx, 0.0, 0.0], [0.0, sy, 0.0], [0.0, 0.0, 1.0]], float)
# -> 1991         self._mtx = np.dot(scale_mtx, self._mtx)
#    1992         self.invalidate()
#    1993         return self
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# # Identification and creation of features

# %% [markdown]
# <font color='teal'>**Create a Pearson correlation heatmap**</font>

# %%
#Calculate the correlation coefficients
corr = dfno.corr()
#plot it in the next line
corr.round(2).style.background_gradient(cmap='coolwarm')
# Out:
# C:\Users\pavilion\Anaconda3\New folder\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# C:\Users\pavilion\Anaconda3\New folder\lib\site-packages\pandas\io\formats\style.py:1089: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# C:\Users\pavilion\Anaconda3\New folder\lib\site-packages\pandas\io\formats\style.py:1090: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
#     #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row0_col1 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row0_col2 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row0_col3 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row0_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row0_col8 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row0_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row0_col10 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row0_col11 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row0_col12 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row0_col13 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row0_col14 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row0_col15 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row0_col16 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row0_col17 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row0_col18 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row0_col19 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row0_col20 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row0_col21 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row0_col22 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row0_col23 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row0_col24 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row1_col0 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row1_col2 {
#             background-color:  #f7a889;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row1_col3 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row1_col7 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row1_col8 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row1_col9 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row1_col10 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row1_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row1_col12 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row1_col13 {
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row1_col14 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row1_col15 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row1_col16 {
#             background-color:  #f7ad90;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row1_col17 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row1_col18 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row1_col19 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row1_col20 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row1_col21 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row1_col22 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row1_col23 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row1_col24 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row2_col0 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row2_col1 {
#             background-color:  #f6a385;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row2_col3 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row2_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row2_col7 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row2_col8 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_a113f2c0_a3a7_11ea_b1a0_30e37a26e7d7row2_col9 {
#             background-color:  #84a7fc;

# %%
corr
# Out:
#                    Unnamed: 0  summit_elev  vertical_drop  base_elev  trams  \
# Unnamed: 0           1.000000    -0.145314       0.030893  -0.165645    NaN
# summit_elev         -0.145314     1.000000       0.617560   0.986872    NaN
# vertical_drop        0.030893     0.617560       1.000000   0.489171    NaN
# base_elev           -0.165645     0.986872       0.489171   1.000000    NaN
# trams                     NaN          NaN            NaN        NaN    NaN
# fastEight                 NaN          NaN            NaN        NaN    NaN
# fastSixes                 NaN          NaN            NaN        NaN    NaN
# fastQuads           -0.035330     0.146606       0.397268   0.083304    NaN
# quad                -0.024201    -0.053877      -0.058167  -0.057776    NaN
# triple              -0.197321     0.058369       0.071986   0.051407    NaN
# double               0.025276     0.098646       0.245009   0.064306    NaN
# surface             -0.068676    -0.376695      -0.330814  -0.350203    NaN
# total_chairs        -0.124283    -0.099769       0.062795  -0.122288    NaN
# Runs                -0.002819     0.495840       0.737347   0.406050    NaN
# TerrainParks        -0.061997     0.040089       0.127476   0.020391    NaN
# LongestRun_mi       -0.002108     0.372964       0.629291   0.293355    NaN
# SkiableTerrain_ac   -0.146898     0.619198       0.670828   0.560112    NaN
# Snow Making_ac      -0.036216    -0.063967       0.221828  -0.117744    NaN
# daysOpenLastYear    -0.137546     0.294226       0.267854   0.267515    NaN
# yearsOpen           -0.106680     0.213305       0.259744   0.184501    NaN
# averageSnowfall     -0.116438     0.680896       0.575600   0.646120    NaN
# AdultWeekday         0.007432     0.408097       0.578112   0.333424    NaN
# AdultWeekend         0.059621     0.246596       0.524463   0.164509    NaN
# projectedDaysOpen   -0.220894     0.293681       0.314482   0.256469    NaN
# NightSkiing_ac      -0.108825     0.242604       0.216633   0.228316    NaN
#
#                    fastEight  fastSixes  fastQuads      quad    triple  ...  \
# Unnamed: 0               NaN        NaN  -0.035330 -0.024201 -0.197321  ...
# summit_elev              NaN        NaN   0.146606 -0.053877  0.058369  ...
# vertical_drop            NaN        NaN   0.397268 -0.058167  0.071986  ...
# base_elev                NaN        NaN   0.083304 -0.057776  0.051407  ...
# trams                    NaN        NaN        NaN       NaN       NaN  ...
# fastEight                NaN        NaN        NaN       NaN       NaN  ...
# fastSixes                NaN        NaN        NaN       NaN       NaN  ...
# fastQuads                NaN        NaN   1.000000  0.135179  0.173846  ...
# quad                     NaN        NaN   0.135179  1.000000  0.159399  ...
# triple                   NaN        NaN   0.173846  0.159399  1.000000  ...
# double                   NaN        NaN   0.144084 -0.167524 -0.117774  ...
# surface                  NaN        NaN   0.059064  0.200132  0.115689  ...
# total_chairs             NaN        NaN   0.435689  0.368919  0.522019  ...
# Runs                     NaN        NaN   0.369169  0.065598  0.125104  ...
# TerrainParks             NaN        NaN   0.269674  0.125986  0.324461  ...
# LongestRun_mi            NaN        NaN   0.382509 -0.034104  0.105367  ...
# SkiableTerrain_ac        NaN        NaN   0.192521 -0.078513 -0.033656  ...
# Snow Making_ac           NaN        NaN   0.438951  0.217268  0.321957  ...
# daysOpenLastYear         NaN        NaN   0.221242  0.142085  0.067221  ...
# yearsOpen                NaN        NaN   0.020800 -0.075668 -0.030248  ...
# averageSnowfall          NaN        NaN   0.078593 -0.194794 -0.012861  ...
# AdultWeekday             NaN        NaN   0.462112  0.147980  0.235573  ...
# AdultWeekend             NaN        NaN   0.466559  0.231457  0.307098  ...
# projectedDaysOpen        NaN        NaN   0.239656  0.106365  0.088960  ...
# NightSkiing_ac           NaN        NaN   0.387102  0.154870  0.358064  ...
#
#                    LongestRun_mi  SkiableTerrain_ac  Snow Making_ac  \
# Unnamed: 0             -0.002108          -0.146898       -0.036216
# summit_elev             0.372964           0.619198       -0.063967
# vertical_drop           0.629291           0.670828        0.221828
# base_elev               0.293355           0.560112       -0.117744
# trams                        NaN                NaN             NaN
# fastEight                    NaN                NaN             NaN
# fastSixes                    NaN                NaN             NaN
# fastQuads               0.382509           0.192521        0.438951
# quad                   -0.034104          -0.078513        0.217268
# triple                  0.105367          -0.033656        0.321957
# double                  0.210837           0.282742        0.227716
# surface                -0.180582          -0.261957        0.038276
# total_chairs            0.140783           0.023235        0.437930
# Runs                    0.662858           0.564606        0.436613
# TerrainParks            0.201987           0.142831        0.372920
# LongestRun_mi           1.000000           0.428964        0.337177
# SkiableTerrain_ac       0.428964           1.000000       -0.005556
# Snow Making_ac          0.337177          -0.005556        1.000000
# daysOpenLastYear        0.148416           0.144111        0.230556
# yearsOpen               0.110155           0.179763        0.094828
# averageSnowfall         0.354528           0.567892       -0.055241
# AdultWeekday            0.458767           0.317109        0.423524
# AdultWeekend            0.449692           0.203867        0.487052
# projectedDaysOpen       0.223496           0.208327        0.234094
# NightSkiing_ac          0.256409           0.188330        0.718599
#
#                    daysOpenLastYear  yearsOpen  averageSnowfall  AdultWeekday  \
# Unnamed: 0                -0.137546  -0.106680        -0.116438      0.007432
# summit_elev                0.294226   0.213305         0.680896      0.408097
# vertical_drop              0.267854   0.259744         0.575600      0.578112
# base_elev                  0.267515   0.184501         0.646120      0.333424
# trams                           NaN        NaN              NaN           NaN
# fastEight                       NaN        NaN              NaN           NaN
# fastSixes                       NaN        NaN              NaN           NaN
# fastQuads                  0.221242   0.020800         0.078593      0.462112
# quad                       0.142085  -0.075668        -0.194794      0.147980
# triple                     0.067221  -0.030248        -0.012861      0.235573
# double                     0.057716   0.215821         0.151354      0.224638
# surface                   -0.008974  -0.102316        -0.356662     -0.134659
# total_chairs               0.140483   0.035885        -0.142887      0.294201
# Runs                       0.250127   0.271454         0.449151      0.583179
# TerrainParks               0.102261   0.071171         0.051379      0.195235
# LongestRun_mi              0.148416   0.110155         0.354528      0.458767
# SkiableTerrain_ac          0.144111   0.179763         0.567892      0.317109
# Snow Making_ac             0.230556   0.094828        -0.055241      0.423524
# daysOpenLastYear           1.000000   0.168785         0.367578      0.327284
# yearsOpen                  0.168785   1.000000         0.269881      0.109978
# averageSnowfall            0.367578   0.269881         1.000000      0.366452
# AdultWeekday               0.327284   0.109978         0.366452      1.000000
# AdultWeekend               0.310033   0.090760         0.212056      0.831069
# projectedDaysOpen          0.756025   0.199167         0.408618      0.399325
# NightSkiing_ac             0.272951   0.170515         0.235066      0.372737
#
#                    AdultWeekend  projectedDaysOpen  NightSkiing_ac
# Unnamed: 0             0.059621          -0.220894       -0.108825
# summit_elev            0.246596           0.293681        0.242604
# vertical_drop          0.524463           0.314482        0.216633
# base_elev              0.164509           0.256469        0.228316
# trams                       NaN                NaN             NaN
# fastEight                   NaN                NaN             NaN
# fastSixes                   NaN                NaN             NaN
# fastQuads              0.466559           0.239656        0.387102
# quad                   0.231457           0.106365        0.154870
# triple                 0.307098           0.088960        0.358064
# double                 0.231374           0.139451        0.290786
# surface               -0.089823          -0.040596       -0.014002
# total_chairs           0.375674           0.173123        0.432314
# Runs                   0.548276           0.300746        0.315998
# TerrainParks           0.281876           0.153831        0.431850
# LongestRun_mi          0.449692           0.223496        0.256409
# SkiableTerrain_ac      0.203867           0.208327        0.188330
# Snow Making_ac         0.487052           0.234094        0.718599
# daysOpenLastYear       0.310033           0.756025        0.272951
# yearsOpen              0.090760           0.199167        0.170515
# averageSnowfall        0.212056           0.408618        0.235066
# AdultWeekday           0.831069           0.399325        0.372737
# AdultWeekend           1.000000           0.315007        0.367362
# projectedDaysOpen      0.315007           1.000000        0.270353
# NightSkiing_ac         0.367362           0.270353        1.000000
#
# [25 rows x 25 columns]

# %% [markdown]
# When reviewing the Pearson correlation coefficient heatmap, you can see substantial differences in the correlations compared to the response variable(s) as well as in the features when compared to each other. The heatmap helps identify features that suffer from multi-collinearity.

# %% [markdown]
# <font color='teal'>**Use the correlation matrix displayed in the heatmap to select and remove collinear features. Remember to exclude the response variable(s) from the matrix to ensure they are retained in your final model development dataset. Then select those features that are more than 95% correlated for removal.**</font>
#
# Step 1: Create a correlation matrix that excludes your response variables.
#
# Step 2: Select the upper triangle of the correlation matrix. This is because a correlation matrix actually contains the same information, twice over!
#
# Step 3: Find the index of feature columns with a correlation greater than 0.95.

# %%
# Step 1. Call the variable corr_matrix
corr_matrix = dfno.drop(['AdultWeekday','AdultWeekend','daysOpenLastYear','projectedDaysOpen'], axis=1).corr().abs()

# Step 2. Uncomment the following code to get the upper triangle of the correlation matrix 
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Step 3. This code iterates through our columns and gets the index of any that have a correlation > 0.95
# Call the variable to_drop, get the columns of our 'upper' variable, make sure the threshold is 0.95.
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
corr_matrix
# Out:
#                    Unnamed: 0  summit_elev  vertical_drop  base_elev  trams  \
# Unnamed: 0           1.000000     0.145314       0.030893   0.165645    NaN
# summit_elev          0.145314     1.000000       0.617560   0.986872    NaN
# vertical_drop        0.030893     0.617560       1.000000   0.489171    NaN
# base_elev            0.165645     0.986872       0.489171   1.000000    NaN
# trams                     NaN          NaN            NaN        NaN    NaN
# fastEight                 NaN          NaN            NaN        NaN    NaN
# fastSixes                 NaN          NaN            NaN        NaN    NaN
# fastQuads            0.035330     0.146606       0.397268   0.083304    NaN
# quad                 0.024201     0.053877       0.058167   0.057776    NaN
# triple               0.197321     0.058369       0.071986   0.051407    NaN
# double               0.025276     0.098646       0.245009   0.064306    NaN
# surface              0.068676     0.376695       0.330814   0.350203    NaN
# total_chairs         0.124283     0.099769       0.062795   0.122288    NaN
# Runs                 0.002819     0.495840       0.737347   0.406050    NaN
# TerrainParks         0.061997     0.040089       0.127476   0.020391    NaN
# LongestRun_mi        0.002108     0.372964       0.629291   0.293355    NaN
# SkiableTerrain_ac    0.146898     0.619198       0.670828   0.560112    NaN
# Snow Making_ac       0.036216     0.063967       0.221828   0.117744    NaN
# yearsOpen            0.106680     0.213305       0.259744   0.184501    NaN
# averageSnowfall      0.116438     0.680896       0.575600   0.646120    NaN
# NightSkiing_ac       0.108825     0.242604       0.216633   0.228316    NaN
#
#                    fastEight  fastSixes  fastQuads      quad    triple  ...  \
# Unnamed: 0               NaN        NaN   0.035330  0.024201  0.197321  ...
# summit_elev              NaN        NaN   0.146606  0.053877  0.058369  ...
# vertical_drop            NaN        NaN   0.397268  0.058167  0.071986  ...
# base_elev                NaN        NaN   0.083304  0.057776  0.051407  ...
# trams                    NaN        NaN        NaN       NaN       NaN  ...
# fastEight                NaN        NaN        NaN       NaN       NaN  ...
# fastSixes                NaN        NaN        NaN       NaN       NaN  ...
# fastQuads                NaN        NaN   1.000000  0.135179  0.173846  ...
# quad                     NaN        NaN   0.135179  1.000000  0.159399  ...
# triple                   NaN        NaN   0.173846  0.159399  1.000000  ...
# double                   NaN        NaN   0.144084  0.167524  0.117774  ...
# surface                  NaN        NaN   0.059064  0.200132  0.115689  ...
# total_chairs             NaN        NaN   0.435689  0.368919  0.522019  ...
# Runs                     NaN        NaN   0.369169  0.065598  0.125104  ...
# TerrainParks             NaN        NaN   0.269674  0.125986  0.324461  ...
# LongestRun_mi            NaN        NaN   0.382509  0.034104  0.105367  ...
# SkiableTerrain_ac        NaN        NaN   0.192521  0.078513  0.033656  ...
# Snow Making_ac           NaN        NaN   0.438951  0.217268  0.321957  ...
# yearsOpen                NaN        NaN   0.020800  0.075668  0.030248  ...
# averageSnowfall          NaN        NaN   0.078593  0.194794  0.012861  ...
# NightSkiing_ac           NaN        NaN   0.387102  0.154870  0.358064  ...
#
#                     surface  total_chairs      Runs  TerrainParks  \
# Unnamed: 0         0.068676      0.124283  0.002819      0.061997
# summit_elev        0.376695      0.099769  0.495840      0.040089
# vertical_drop      0.330814      0.062795  0.737347      0.127476
# base_elev          0.350203      0.122288  0.406050      0.020391
# trams                   NaN           NaN       NaN           NaN
# fastEight               NaN           NaN       NaN           NaN
# fastSixes               NaN           NaN       NaN           NaN
# fastQuads          0.059064      0.435689  0.369169      0.269674
# quad               0.200132      0.368919  0.065598      0.125986
# triple             0.115689      0.522019  0.125104      0.324461
# double             0.033737      0.463955  0.347692      0.317505
# surface            1.000000      0.621067  0.207004      0.215930
# total_chairs       0.621067      1.000000  0.233159      0.521725
# Runs               0.207004      0.233159  1.000000      0.355062
# TerrainParks       0.215930      0.521725  0.355062      1.000000
# LongestRun_mi      0.180582      0.140783  0.662858      0.201987
# SkiableTerrain_ac  0.261957      0.023235  0.564606      0.142831
# Snow Making_ac     0.038276      0.437930  0.436613      0.372920
# yearsOpen          0.102316      0.035885  0.271454      0.071171
# averageSnowfall    0.356662      0.142887  0.449151      0.051379
# NightSkiing_ac     0.014002      0.432314  0.315998      0.431850
#
#                    LongestRun_mi  SkiableTerrain_ac  Snow Making_ac  \
# Unnamed: 0              0.002108           0.146898        0.036216
# summit_elev             0.372964           0.619198        0.063967
# vertical_drop           0.629291           0.670828        0.221828
# base_elev               0.293355           0.560112        0.117744
# trams                        NaN                NaN             NaN
# fastEight                    NaN                NaN             NaN
# fastSixes                    NaN                NaN             NaN
# fastQuads               0.382509           0.192521        0.438951
# quad                    0.034104           0.078513        0.217268
# triple                  0.105367           0.033656        0.321957
# double                  0.210837           0.282742        0.227716
# surface                 0.180582           0.261957        0.038276
# total_chairs            0.140783           0.023235        0.437930
# Runs                    0.662858           0.564606        0.436613
# TerrainParks            0.201987           0.142831        0.372920
# LongestRun_mi           1.000000           0.428964        0.337177
# SkiableTerrain_ac       0.428964           1.000000        0.005556
# Snow Making_ac          0.337177           0.005556        1.000000
# yearsOpen               0.110155           0.179763        0.094828
# averageSnowfall         0.354528           0.567892        0.055241
# NightSkiing_ac          0.256409           0.188330        0.718599
#
#                    yearsOpen  averageSnowfall  NightSkiing_ac
# Unnamed: 0          0.106680         0.116438        0.108825
# summit_elev         0.213305         0.680896        0.242604
# vertical_drop       0.259744         0.575600        0.216633
# base_elev           0.184501         0.646120        0.228316
# trams                    NaN              NaN             NaN
# fastEight                NaN              NaN             NaN
# fastSixes                NaN              NaN             NaN
# fastQuads           0.020800         0.078593        0.387102
# quad                0.075668         0.194794        0.154870
# triple              0.030248         0.012861        0.358064
# double              0.215821         0.151354        0.290786
# surface             0.102316         0.356662        0.014002
# total_chairs        0.035885         0.142887        0.432314
# Runs                0.271454         0.449151        0.315998
# TerrainParks        0.071171         0.051379        0.431850
# LongestRun_mi       0.110155         0.354528        0.256409
# SkiableTerrain_ac   0.179763         0.567892        0.188330
# Snow Making_ac      0.094828         0.055241        0.718599
# yearsOpen           1.000000         0.269881        0.170515
# averageSnowfall     0.269881         1.000000        0.235066
# NightSkiing_ac      0.170515         0.235066        1.000000
#
# [21 rows x 21 columns]

# %%
upper.head()
# Out:
#                Unnamed: 0  summit_elev  vertical_drop  base_elev  trams  \
# Unnamed: 0            NaN     0.145314       0.030893   0.165645    NaN
# summit_elev           NaN          NaN       0.617560   0.986872    NaN
# vertical_drop         NaN          NaN            NaN   0.489171    NaN
# base_elev             NaN          NaN            NaN        NaN    NaN
# trams                 NaN          NaN            NaN        NaN    NaN
#
#                fastEight  fastSixes  fastQuads      quad    triple  ...  \
# Unnamed: 0           NaN        NaN   0.035330  0.024201  0.197321  ...
# summit_elev          NaN        NaN   0.146606  0.053877  0.058369  ...
# vertical_drop        NaN        NaN   0.397268  0.058167  0.071986  ...
# base_elev            NaN        NaN   0.083304  0.057776  0.051407  ...
# trams                NaN        NaN        NaN       NaN       NaN  ...
#
#                 surface  total_chairs      Runs  TerrainParks  LongestRun_mi  \
# Unnamed: 0     0.068676      0.124283  0.002819      0.061997       0.002108
# summit_elev    0.376695      0.099769  0.495840      0.040089       0.372964
# vertical_drop  0.330814      0.062795  0.737347      0.127476       0.629291
# base_elev      0.350203      0.122288  0.406050      0.020391       0.293355
# trams               NaN           NaN       NaN           NaN            NaN
#
#                SkiableTerrain_ac  Snow Making_ac  yearsOpen  averageSnowfall  \
# Unnamed: 0              0.146898        0.036216   0.106680         0.116438
# summit_elev             0.619198        0.063967   0.213305         0.680896
# vertical_drop           0.670828        0.221828   0.259744         0.575600
# base_elev               0.560112        0.117744   0.184501         0.646120
# trams                        NaN             NaN        NaN              NaN
#
#                NightSkiing_ac
# Unnamed: 0           0.108825
# summit_elev          0.242604
# vertical_drop        0.216633
# base_elev            0.228316
# trams                     NaN
#
# [5 rows x 21 columns]

# %%
# Let's see those features! 
print('Features selected to drop include:',to_drop)
# Out:
# Features selected to drop include: ['base_elev']

# %%
print('Reduced dataframe size: ',dfno.drop(dfno[to_drop], axis=1).shape)
# Out:
# Reduced dataframe size:  (175, 26)

# %%
# Now replace dfno by the result of dropping the columns in the to_drop variable from it
dfno = dfno.drop(dfno[to_drop], axis=1)

# %% [markdown]
# Now we address the feature creation piece of this step. We can create additional features through many methods such as: combining several features, grouping features into bins, or even by applying an unsupervised classification algorithm, such as k-means clustering and using the clusters as features in our model development dataset.
#
# Clustering essentially finds patterns in data when we don't know in advance what we're looking for. The K-means algorithm is one way of doing clustering. It puts our data into groups (or 'clusters') which can then become features for further analysis. What the k-means algorithm outputs, though, depends on the number of clusters we set out to have. We will use a method called 'Elbow plotting' to determine this number.
#
# We will cover clustering and k-means thoroughly in the Unsupervised Learning unit of this course, but for now, we'll use it for feature creation alone, which is an integral part of Exploratory Data Analysis. Don't worry if you don't understand the details just yet.

# %% [markdown]
# Run the next two cells below to create an Elbow plot. The Elbow plot is a diagnostic tool that helps us determine the number of clusters to include in our k-means clustering implementation.
#
# In this example, the error between clusters and within clusters is compared for a range of 1 to 11 clusters, and it appears the elbow is between two and four, therefore we set the parameter k = 3.

# %%
dfno_1=dfno.fillna(0)

# %%
from sklearn.cluster import KMeans
x = dfno_1.drop(['Name','state'], axis =1).values

# %%
x
# Out:
# array([[2.00000000e+00, 2.09000000e+03, 2.94000000e+02, ...,
#         3.40000000e+01, 1.52000000e+02, 3.00000000e+01],
#        [4.00000000e+00, 1.11000000e+04, 1.80000000e+03, ...,
#         7.80000000e+01, 1.04000000e+02, 8.00000000e+01],
#        [5.00000000e+00, 7.80000000e+03, 6.00000000e+02, ...,
#         4.70000000e+01, 1.07000000e+02, 0.00000000e+00],
#        ...,
#        [3.27000000e+02, 7.80800000e+03, 1.57100000e+03, ...,
#         5.90000000e+01, 1.23000000e+02, 1.10000000e+02],
#        [3.28000000e+02, 9.66300000e+03, 9.90000000e+02, ...,
#         4.90000000e+01, 1.20053004e+02, 0.00000000e+00],
#        [3.29000000e+02, 9.50000000e+03, 1.10000000e+03, ...,
#         4.90000000e+01, 1.20053004e+02, 0.00000000e+00]])

# %%
Error =[]
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i).fit(x)
    kmeans.fit(x)
    Error.append(kmeans.inertia_)
import matplotlib.pyplot as plt
plt.plot(range(1, 11), Error)
plt.title('Elbow method')
plt.xlabel('No of clusters')
plt.ylabel('Error')
plt.show()

# %% [markdown]
# <font color='teal'>**Fit the kmeans algorithm with the k parameter set to three and plot the results.**</font>

# %%
# This code will fit the k-means algorithm with our k parameter set to three, and plot the results. Cool, huh? 
kmeans3 = KMeans(n_clusters=3)
y_kmeans3 = kmeans3.fit_predict(x)
plt.scatter(x[:, 0], x[:, 1], c=y_kmeans3, s=50, cmap='viridis')

centers = kmeans3.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %% [markdown]
# <font color='teal'>**Add the clusters to your dataframe as a new column to include in the next step and write the updated dataframe out as csv. Save the dataframe in the data folder and name it `step3_output.csv`.**</font>

# %%
# Make a new column in your dfno dataframe called 'clusters', and assign it the variable: y_kmeans3
dfno_1['clusters'] = y_kmeans3

# %%
# Write your dataframe to csv 
dfno_1.to_csv('step3_output.csv')
